# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("car data.csv")
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ciaz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# Checking null values

# %%
data.isnull().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# Outlier detection

# %%
data.drop("Car_Name",axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
plt.boxplot(data.Present_Price)
plt.show()

# %%
plt.boxplot(data.Selling_Price)
plt.show()

# %%
plt.boxplot(data.Kms_Driven)
plt.show()

# %% [markdown]
# Visualisation of Labels

# %%
trans_type=data.Transmission.value_counts()

# %%
label=["Manual","Automatic"]

# %%
plt.pie(x=trans_type.values,labels=label,autopct="%1.1f%%")
plt.show()

# %%
data.Fuel_Type.value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
sns.countplot(x="Fuel_Type",data=data)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='count'>

# %%
data.Seller_Type.value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
sns.countplot(x="Seller_Type",data=data)
# Out:
# <Axes: xlabel='Seller_Type', ylabel='count'>

# %%
Visualisation of Data distribution

# %%
sns.distplot(data.Present_Price,kde=True)
plt.show()
# Out:
# C:\Users\zapha\AppData\Local\Temp\ipykernel_12964\2998636338.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Present_Price,kde=True)

# %%
sns.distplot(data.Selling_Price,kde=True)
plt.show()
# Out:
# C:\Users\zapha\AppData\Local\Temp\ipykernel_12964\2557484252.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Selling_Price,kde=True)

# %%
sns.histplot(data['Kms_Driven'], kde=True)
plt.show()
